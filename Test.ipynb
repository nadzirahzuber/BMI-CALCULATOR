# %% [markdown]
# <a href="https://colab.research.google.com/github/nadzirahzuber/BMI-CALCULATOR/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name =input("siapa nama? : ")
print("Hello",name)

print("Awak dari mana?")
city = input()
print("ooo dari",city)
# Out:
# siapa nama? : naddy
# Hello naddy
# Awak dari mana?
# perak
# ooo dari perak

# %%
# BMI CALCULATOR
name = input("What's your name?: ")
print("Hello",name)
weight =float(input("What is your weight? in kg: "))
print("Your weight is",weight)
height =float(input("What is your height? In cm: "))
print("Your height is",height)
h_m = height/100
calculate_BMI = weight/(h_m*h_m)
print(f"Hi{name}Your BMI is{calculate_BMI}")
# Out:
# What's your name?: huh
# Hello huh
# What is your weight? in kg: 54
# Your weight is 54.0
# What is your height? In cm: 146
# Your height is 146.0
# HihuhYour BMI is25.333083130043164
